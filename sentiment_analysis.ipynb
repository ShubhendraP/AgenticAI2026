# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhendraP/AgenticAI2026/blob/weekly-classes/sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

import string

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# -----------------------------
# Download NLTK Data (run once)
# -----------------------------

nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# -----------------------------
# Small Dataset
# -----------------------------

sentences = [

"I love this movie",
"This film was amazing",

"I hated this movie",
"The acting was terrible",

"What a fantastic experience",
"This was very boring",

"I really enjoyed the story",
"The movie was bad"

]

labels = [

"positive",
"positive",

"negative",
"negative",

"positive",
"negative",

"positive",
"negative"

]

# %%
# -----------------------------
# Lemmatizer Setup
# -----------------------------

lemmatizer = WordNetLemmatizer()

stop_words = set(stopwords.words("english"))

# %%
# -----------------------------
# Text Cleaning Function
# -----------------------------

def preprocess(text):

    # lower case
    text = text.lower()

    # remove punctuation
    text = text.translate(
        str.maketrans("", "", string.punctuation)
    )

    # tokenize
    words = nltk.word_tokenize(text)

    # remove stopwords + lemmatize
    cleaned_words = [

        lemmatizer.lemmatize(word)

        for word in words

        if word not in stop_words
    ]

    return " ".join(cleaned_words)

# %%
# -----------------------------
# Apply preprocessing
# -----------------------------

nltk.download("punkt_tab")

processed_sentences = [

    preprocess(sentence)

    for sentence in sentences
]

print("\nProcessed Sentences:")
print(processed_sentences)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Processed Sentences:
# ['love movie', 'film amazing', 'hated movie', 'acting terrible', 'fantastic experience', 'boring', 'really enjoyed story', 'movie bad']

# %%
# -----------------------------
# Bag Of Words
# -----------------------------

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(processed_sentences)

# %%
# -----------------------------
# Train Test Split
# -----------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X,
    labels,
    test_size=0.25,
    random_state=42
)

# %%
# -----------------------------
# Naive Bayes Model
# -----------------------------

model = MultinomialNB()

model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# -----------------------------
# Evaluate
# -----------------------------

predictions = model.predict(X_test)

print("\nAccuracy:")
print(accuracy_score(y_test, predictions))
# Out:
# Accuracy:
# 0.5

# %%
# -----------------------------
# Test New Sentence
# -----------------------------

new_sentence = ["I really love this film"]

processed = preprocess(new_sentence[0])

vector = vectorizer.transform([processed])

prediction = model.predict(vector)

print("\nPrediction:", prediction[0])
# Out:
# Prediction: positive

# %% [markdown]
# Raw Text
#  ↓
# Lower Case
#  ↓
# Remove punctuation
#  ↓
# Tokenization
#  ↓
# Stopword removal
#  ↓
# LEMMATIZATION
#  ↓
# Bag Of Words
#  ↓
# Naive Bayes
#  ↓
# Sentiment Prediction
